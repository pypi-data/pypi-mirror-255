# %%
from llama_index.core.command_line.upgrade import upgrade_nb_file

# %%
file_path = "/Users/nerdai/Projects/migration/llama_index/docs/examples/llama_hub/llama_pack_resume.ipynb"

# %%
upgrade_nb_file(file_path)
# Out:
# ...
# lines: ['%pip install llama-index-readers-wikipedia']
#
#
# this_new_lines: ['%pip install llama-index-readers-wikipedia']
# new_lines: ['%pip install llama-index-readers-wikipedia']
# new_installs: []
#
# ...
# lines: ['!pip install llama-index llama-hub']
#
#
# this_new_lines: ['!pip install llama-index llama-hub']
# new_lines: ['!pip install llama-index llama-hub']
# new_installs: []
#
# ...
# lines: ['from llama_index.readers.wikipedia import WikipediaReader\n', '\n', 'loader = WikipediaReader()\n', 'documents = loader.load_data(\n', '    pages=["OpenAI", "Sam Altman", "Mira Murati", "Emmett Shear"],\n', '    auto_suggest=False,\n', ')']
#
#
# this_new_lines: ['from llama_index.readers.wikipedia import WikipediaReader\n']
# this_new_lines: ['\n']
# this_new_lines: ['loader = WikipediaReader()\n']
# this_new_lines: ['documents = loader.load_data(\n']
# this_new_lines: ['    pages=["OpenAI", "Sam Altman", "Mira Murati", "Emmett Shear"],\n']
# this_new_lines: ['    auto_suggest=False,\n']
# ...

# %%
import os

os.path.join(os.pardir)
# Out:
# '..'
